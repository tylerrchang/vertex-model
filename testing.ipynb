# %%
import shapely.plotting
import matplotlib.pyplot as plt
from shapely.geometry import Polygon
import os
import time
import numpy as np

import parsing
import plotting

# %matplotlib inline

# %%
data = parsing.read_data(
    os.path.join("data", "network_vertices.txt"),
    os.path.join("data", "cell_indices.txt")
)

# %%
# This chunk graphs t = 0
plt.figure(figsize = (6,4))
plt.xlim(-1, 6)
plt.ylim(-1, 6)
for v in data.vert_list:
    plt.scatter(v.x, v.y)

for cell in data.cell_list:
    x_poly, y_poly = cell.polygon.exterior.xy
    plt.plot(x_poly, y_poly)

# %%
# This chunk graphs t = 0
lx = 9 * (2 / (3 * (3**0.5)))**0.5
ly = 4 * (2 / (3**0.5))**0.5
plt.figure(figsize = (6,4))
plt.xlim(0, lx)
plt.ylim(0, ly)
for v in data.vert_list:
    plt.scatter(v.x, v.y)

for cell in data.cell_list:
    x_poly, y_poly = cell.polygon.exterior.xy
    plt.plot(x_poly, y_poly)

# for cell in data.cell_list:
# x_poly, y_poly = data.cell_list[0].polygon.exterior.xy
# plt.plot(x_poly, y_poly)

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[53], line 1
# ----> 1 [1, 2] + 2
#
# TypeError: can only concatenate list (not "int") to list

# %%
d = np.array([1, 1])

# %%
d / 2
# Out:
# array([0.5, 0.5])
